# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep, strftime
import random
from random import randint
from selenium import webdriver
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cars = pd.DataFrame(columns = ['brand', 'model', 'price', 'fuel', 'transmission', 'km', 'year', 'location'])
df_cars.head()
# Out:
# Empty DataFrame
# Columns: [brand, model, price, fuel, transmission, km, year, location]
# Index: []

# %%
for i in range(2022):
    
    sleep(randint(2,5))
    url = ('https://niw.es/es/coches-segunda-mano/marca/modelo/page{}'.format(i))
    response = requests.get(url,  headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(response.text, "html.parser")
    all_cars = soup.find_all(class_="column block vehicle-details")
    print(df_cars.shape)
    print('page',i)
    
    for i in range(len(all_cars)):
        car_brand = all_cars[i].find(class_='vehicle__title').text
        car_model = all_cars[i].find(class_='model-trim block').text
        price = all_cars[i].find(class_='vehicle__price').text.replace('\xa0€','').replace('.', '')
        fuel = all_cars[i].find(class_='vehicle__data').text.split('|')[0].strip()
        transmission = all_cars[i].find(class_='vehicle__data').text.split('|')[1].strip()
        
        try:
            km = all_cars[i].find(class_='vehicle__data').text.split('|')[2].replace('\xa0km', '').replace('.', '').strip()
            year = all_cars[i].find(class_='vehicle__data').text.split('|')[3].strip()
            location = all_cars[i].find(class_='vehicle__data').text.split('|')[4].strip()
            
        except:
            km = np.nan
            year = all_cars[i].find(class_='vehicle__data').text.split('|')[2].strip()
            location = all_cars[i].find(class_='vehicle__data').text.split('|')[3].strip()
            
        try:
        
            new_row = {
                'brand': car_brand,
                'model': car_model,
                'price': float(price),
                'fuel': fuel,
                'transmission': transmission,
                'km': float(km),
                'year': int(year),
                'location': location
            }
            
        except:
            
            new_row = {
                'brand': car_brand,
                'model': car_model,
                'price': float(price),
                'fuel': fuel,
                'transmission': transmission,
                'km': float(all_cars[i].find(class_='vehicle__data').text.split('|')[2].replace('\xa0km', '').replace('.', '').strip()),
                'year': np.nan,
                'location': location
            }
        
        df_cars = df_cars.append(new_row, ignore_index=True)
# Out:
# (29985, 8)
# page 1999
# (30000, 8)
# page 2000
# (30015, 8)
# page 2001
# (30030, 8)
# page 2002
# (30045, 8)
# page 2003
# (30060, 8)
# page 2004
# (30075, 8)
# page 2005
# (30090, 8)
# page 2006
# (30105, 8)
# page 2007
# (30120, 8)
# page 2008
# (30135, 8)
# page 2009
# (30150, 8)
# page 2010
# (30165, 8)
# page 2011
# (30180, 8)
# page 2012
# (30195, 8)
# page 2013
# (30210, 8)
# page 2014
# (30225, 8)
# page 2015
# (30240, 8)
# page 2016
# (30255, 8)
# page 2017
# (30270, 8)
# page 2018
# (30285, 8)
# page 2019
# (30300, 8)
# page 2020
# (30315, 8)
# page 2021

# %%
df_cars.shape
# Out:
# (30326, 8)

# %%
df_cars
# Out:
#             brand                                              model    price  \
# 0         Renault              Megane 1.5 DCI 110 ENERGY BOSE 110 5P  14500.0
# 1      Volkswagen     Tiguan Sport R-Line 2.0 TDI DSG7 4Motion 190CV  42490.0
# 2         Hyundai                         i30 1.6 CRDI 81KW TECNO 5P  16300.0
# 3          Nissan  X-Trail 1.3 DIG-T ACENTA DCT 120KW 7 SEAT 160 ...  22400.0
# 4           Cupra                            Leon Sportstourer cupra  36900.0
# ...           ...                                                ...      ...
# 30321        Ford          Focus Focus 1.0 Ecoboost ST Line Aut. 125  18500.0
# 30322        Ford       Focus Focus 1.0 Ecoboost Auto-S&S Trend+ 125  12600.0
# 30323        Ford  Transit Transit Furgón Diesel FT 350 L3 Van Am...  21500.0
# 30324        Ford                    Fiesta Fiesta 1.1 Ti-VCT Trend+  10800.0
# 30325        Ford        EcoSport EcoSport 1.0 EcoBoost Titanium 125  13500.0
#
#            fuel     transmission       km  year   location
# 0        Diésel           Manual  30926.0  2017      Alava
# 1        Diésel       Automático  11855.0  2020     Madrid
# 2        Diésel           Manual   9000.0  2018  Barcelona
# 3      Gasolina       Automático   7253.0  2020      Alava
# 4       Híbrido       Automático      8.0  2020      Soria
# ...         ...              ...      ...   ...        ...
# 30321  Gasolina  Semi-automático  12438.0  2019   Alicante
# 30322  Gasolina           Manual  34980.0  2018   Alicante
# 30323    Diésel           Manual  90000.0  2018   Alicante
# 30324  Gasolina           Manual  32093.0  2018   Alicante
# 30325  Gasolina           Manual  44800.0  2016   Alicante
#
# [30326 rows x 8 columns]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\David Sagrario\\Bootcamp Data Science\\DAT_project'

# %%
df_cars.to_csv(r'C:\\Users\\David Sagrario\\Bootcamp Data Science\\DAT_project\\niw_cars.csv', index = False)

# %%
df_cars = pd.read_csv('niw_cars.csv')

# %%
df_cars[df_cars.duplicated(keep=False)].shape
# Out:
# (5870, 8)

# %%
df_cars.drop_duplicates(keep='first', inplace = True, ignore_index = True)

# %%
df_cars.shape
# Out:
# (26308, 8)

# %%
df_cars.isnull().sum()
# Out:
# brand             0
# model             0
# price             0
# fuel              0
# transmission      0
# km              132
# year              1
# location          0
# dtype: int64

# %%
from collections import Counter

# %%
Counter(df_cars['brand'])
# Out:
# Counter({'Renault': 2325,
#          'Volkswagen': 2523,
#          'Hyundai': 1002,
#          'Nissan': 1309,
#          'Cupra': 27,
#          'Ford': 1737,
#          'Seat': 1993,
#          'Dacia': 109,
#          'Land Rover': 202,
#          'BMW': 1448,
#          'Volvo': 671,
#          'Peugeot': 1145,
#          'Kia': 860,
#          'Opel': 1489,
#          'Citroen': 784,
#          'MINI': 449,
#          'Audi': 2366,
#          'Fiat': 807,
#          'Subaru': 25,
#          'Mazda': 179,
#          'DS': 72,
#          'Honda': 136,
#          'Skoda': 467,
#          'Abarth': 39,
#          'Bentley': 9,
#          'Mercedes-Benz': 2021,
#          'Toyota': 854,
#          'Jeep': 266,
#          'Mitsubishi': 97,
#          'Suzuki': 109,
#          'Smart': 146,
#          'Lexus': 211,
#          'Alfa Romeo': 108,
#          'Infiniti': 15,
#          'Jaguar': 146,
#          'Maserati': 20,
#          'Porsche': 71,
#          'Tesla': 2,
#          'SsangYong': 54,
#          'DFSK': 2,
#          'Drexel': 1,
#          'Ferrari': 4,
#          'ALPINE': 4,
#          'Mahindra': 2,
#          'Aston Martin': 2})

# %%
Counter(df_cars['price'])
# Out:
# Counter({14500.0: 177,
#          42490.0: 5,
#          16300.0: 52,
#          22400.0: 32,
#          36900.0: 94,
#          32990.0: 38,
#          17200.0: 58,
#          14000.0: 21,
#          22500.0: 162,
#          12900.0: 257,
#          16500.0: 217,
#          29990.0: 68,
#          18900.0: 323,
#          16650.0: 4,
#          37890.0: 3,
#          53900.0: 8,
#          36000.0: 16,
#          36890.0: 1,
#          30900.0: 125,
#          44900.0: 60,
#          32500.0: 62,
#          41900.0: 63,
#          46500.0: 17,
#          35900.0: 103,
#          28900.0: 202,
#          9990.0: 70,
#          14750.0: 14,
#          13850.0: 12,
#          26790.0: 5,
#          23000.0: 41,
#          16990.0: 185,
#          28200.0: 14,
#          17900.0: 351,
#          12750.0: 8,
#          24990.0: 108,
#          28990.0: 68,
#          17990.0: 164,
#          23900.0: 258,
#          26500.0: 133,
#          16950.0: 33,
#          11500.0: 149,
#          17500.0: 199,
#          14900.0: 282,
#          17490.0: 65,
#          12990.0: 97,
#          29700.0: 21,
#          29490.0: 20,
#          26400.0: 37,
#          11990.0: 80,
#          28700.0: 18,
#          27670.0: 1,
#          21500.0: 181,
#          20500.0: 229,
#          23550.0: 2,
#          23790.0: 6,
#          23775.0: 1,
#          26300.0: 35,
#          8750.0: 2,
#          27900.0: 221,
#          15900.0: 303,
#          30500.0: 120,
#          10500.0: 155,
#          102455.0: 3,
#          7700.0: 20,
#          19500.0: 161,
#          28720.0: 2,
#          14990.0: 121,
#          11690.0: 3,
#          14290.0: 14,
#          64900.0: 18,
#          41500.0: 18,
#          58900.0: 15,
#          15100.0: 26,
#          10700.0: 24,
#          12700.0: 54,
#          29100.0: 16,
#          33900.0: 119,
#          13000.0: 32,
#          22900.0: 244,
#          28600.0: 29,
#          24600.0: 16,
#          7000.0: 2,
#          18700.0: 38,
#          13900.0: 275,
#          13300.0: 27,
#          10195.0: 2,
#          10290.0: 5,
#          12100.0: 9,
#          10830.0: 1,
#          13350.0: 3,
#          11700.0: 14,
#          18300.0: 45,
#          27800.0: 23,
#          23500.0: 130,
#          22100.0: 34,
#          21900.0: 277,
#          18200.0: 44,
#          29900.0: 211,
#          14600.0: 27,
#          13200.0: 39,
#          38900.0: 90,
#          31900.0: 159,
#          24790.0: 5,
#          55000.0: 9,
#          16900.0: 324,
#          16400.0: 51,
#          14450.0: 24,
#          24800.0: 14,
#          9500.0: 82,
#          20000.0: 18,
#          19900.0: 320,
#          9900.0: 150,
#          287980.0: 1,
#          69900.0: 21,
#          56900.0: 11,
#          307900.0: 2,
#          27500.0: 105,
#          299000.0: 2,
#          47600.0: 2,
#          216750.0: 2,
#          39700.0: 8,
#          259900.0: 2,
#          33500.0: 50,
#          31800.0: 11,
#          38500.0: 43,
#          24900.0: 247,
#          24400.0: 32,
#          29400.0: 19,
#          25700.0: 26,
#          20990.0: 126,
#          30200.0: 6,
#          13500.0: 138,
#          14650.0: 8,
#          25900.0: 203,
#          13800.0: 33,
#          30100.0: 7,
#          43490.0: 2,
#          8900.0: 85,
#          37490.0: 7,
#          10080.0: 2,
#          9780.0: 1,
#          21700.0: 44,
#          6990.0: 7,
#          38990.0: 21,
#          18990.0: 159,
#          11650.0: 3,
#          13490.0: 64,
#          42900.0: 52,
#          41400.0: 3,
#          28095.0: 4,
#          37995.0: 3,
#          28444.0: 1,
#          31295.0: 3,
#          47895.0: 2,
#          12600.0: 22,
#          34900.0: 139,
#          33200.0: 4,
#          18190.0: 5,
#          11950.0: 10,
#          14495.0: 10,
#          16495.0: 14,
#          14950.0: 22,
#          14995.0: 10,
#          32900.0: 119,
#          26900.0: 176,
#          10900.0: 160,
#          20900.0: 327,
#          18500.0: 204,
#          16000.0: 35,
#          27950.0: 14,
#          46800.0: 5,
#          15990.0: 173,
#          13990.0: 127,
#          59900.0: 26,
#          11900.0: 179,
#          39000.0: 21,
#          17890.0: 14,
#          19170.0: 1,
#          88100.0: 1,
#          55900.0: 14,
#          24995.0: 4,
#          26800.0: 21,
#          18890.0: 14,
#          45500.0: 18,
#          23400.0: 57,
#          19700.0: 34,
#          31500.0: 93,
#          43900.0: 44,
#          16456.0: 1,
#          28247.0: 1,
#          30950.0: 7,
#          31850.0: 2,
#          30550.0: 1,
#          27550.0: 1,
#          15500.0: 175,
#          32200.0: 5,
#          20450.0: 16,
#          15300.0: 41,
#          20220.0: 2,
#          26290.0: 5,
#          58298.0: 1,
#          28850.0: 5,
#          20100.0: 19,
#          72500.0: 2,
#          44600.0: 6,
#          67500.0: 1,
#          34630.0: 1,
#          18630.0: 1,
#          34999.0: 3,
#          20800.0: 32,
#          40800.0: 8,
#          13700.0: 46,
#          15650.0: 14,
#          21460.0: 2,
#          16800.0: 57,
#          11850.0: 10,
#          20875.0: 1,
#          32000.0: 19,
#          11800.0: 50,
#          11300.0: 20,
#          24890.0: 9,
#          24300.0: 26,
#          27300.0: 19,
#          229000.0: 1,
#          24500.0: 111,
#          38890.0: 1,
#          33990.0: 40,
#          32400.0: 9,
#          18880.0: 3,
#          15400.0: 55,
#          29500.0: 89,
#          39500.0: 39,
#          42890.0: 2,
#          28650.0: 3,
#          19100.0: 25,
#          26100.0: 9,
#          14175.0: 1,
#          17100.0: 19,
#          47300.0: 2,
#          35500.0: 57,
#          10600.0: 13,
#          79000.0: 3,
#          45000.0: 9,
#          19800.0: 29,
#          20690.0: 16,
#          9700.0: 26,
#          8500.0: 87,
#          7990.0: 17,
#          15800.0: 29,
#          25990.0: 70,
#          15200.0: 108,
#          23800.0: 49,
#          21400.0: 85,
#          25500.0: 84,
#          12500.0: 162,
#          10790.0: 2,
#          34800.0: 12,
#          23990.0: 72,
#          30000.0: 12,
#          56500.0: 4,
#          42500.0: 27,
#          28100.0: 19,
#          41100.0: 2,
#          22490.0: 39,
#          27490.0: 17,
#          28490.0: 22,
#          29590.0: 1,
#          18490.0: 50,
#          23490.0: 32,
#          19990.0: 154,
#          15250.0: 19,
#          23250.0: 14,
#          22350.0: 3,
#          22750.0: 6,
#          28950.0: 2,
#          27990.0: 75,
#          35990.0: 32,
#          36190.0: 2,
#          48290.0: 1,
#          39300.0: 11,
#          46900.0: 37,
#          59990.0: 2,
#          44500.0: 15,
#          37389.0: 4,
#          15695.0: 1,
#          26560.0: 1,
#          16745.0: 1,
#          24860.0: 1,
#          25995.0: 8,
#          20270.0: 1,
#          25895.0: 3,
#          22725.0: 1,
#          33700.0: 14,
#          37500.0: 26,
#          15600.0: 29,
#          14200.0: 46,
#          19400.0: 36,
#          15750.0: 51,
#          21800.0: 36,
#          17400.0: 36,
#          21000.0: 33,
#          23950.0: 18,
#          15690.0: 12,
#          17790.0: 14,
#          25100.0: 19,
#          38000.0: 17,
#          8700.0: 36,
#          17375.0: 1,
#          47880.0: 1,
#          14350.0: 7,
#          28690.0: 5,
#          22990.0: 123,
#          30490.0: 14,
#          24240.0: 1,
#          21950.0: 28,
#          15450.0: 17,
#          43990.0: 18,
#          40890.0: 2,
#          28500.0: 100,
#          19390.0: 5,
#          39900.0: 97,
#          24000.0: 36,
#          17750.0: 27,
#          22300.0: 40,
#          22000.0: 27,
#          61400.0: 1,
#          43600.0: 7,
#          42600.0: 5,
#          49800.0: 2,
#          49300.0: 3,
#          29890.0: 6,
#          36200.0: 15,
#          28510.0: 1,
#          32800.0: 9,
#          28890.0: 7,
#          28800.0: 19,
#          28790.0: 2,
#          37800.0: 11,
#          12390.0: 9,
#          46970.0: 1,
#          40400.0: 6,
#          20987.0: 1,
#          35600.0: 6,
#          12989.0: 1,
#          11236.0: 1,
#          10654.0: 2,
#          10789.0: 5,
#          10987.0: 1,
#          19874.0: 1,
#          34500.0: 51,
#          43326.0: 1,
#          62900.0: 18,
#          17300.0: 42,
#          16600.0: 25,
#          36500.0: 39,
#          10899.0: 1,
#          17000.0: 32,
#          37900.0: 106,
#          19200.0: 23,
#          21630.0: 1,
#          12650.0: 7,
#          19870.0: 4,
#          17920.0: 1,
#          7900.0: 42,
#          19300.0: 53,
#          14800.0: 38,
#          23995.0: 9,
#          29000.0: 17,
#          12120.0: 1,
#          16850.0: 11,
#          51900.0: 21,
#          12200.0: 20,
#          12490.0: 40,
#          19490.0: 43,
#          18790.0: 14,
#          37100.0: 6,
#          51100.0: 3,
#          32100.0: 12,
#          31100.0: 5,
#          26990.0: 81,
#          28400.0: 18,
#          10990.0: 95,
#          37950.0: 5,
#          47990.0: 8,
#          42990.0: 18,
#          9300.0: 16,
#          13600.0: 16,
#          8490.0: 8,
#          16490.0: 74,
#          25790.0: 3,
#          24390.0: 2,
#          34990.0: 35,
#          19000.0: 30,
#          20390.0: 3,
#          20490.0: 46,
#          40500.0: 13,
#          30990.0: 57,
#          37990.0: 27,
#          29950.0: 10,
#          14190.0: 14,
#          24950.0: 7,
#          19600.0: 37,
#          39800.0: 7,
#          8990.0: 44,
#          49850.0: 2,
#          26850.0: 6,
#          18590.0: 6,
#          23450.0: 6,
#          22950.0: 12,
#          16450.0: 27,
#          15950.0: 36,
#          11495.0: 22,
#          43500.0: 23,
#          22700.0: 25,
#          22600.0: 28,
#          36400.0: 6,
#          40700.0: 17,
#          23190.0: 3,
#          17600.0: 37,
#          31290.0: 3,
#          26620.0: 5,
#          30620.0: 1,
#          18710.0: 5,
#          11490.0: 46,
#          34600.0: 8,
#          44300.0: 7,
#          66200.0: 1,
#          62125.0: 1,
#          23890.0: 27,
#          24690.0: 6,
#          27200.0: 16,
#          11256.0: 1,
#          12987.0: 3,
#          31751.0: 1,
#          11489.0: 1,
#          40770.0: 1,
#          18100.0: 16,
#          34690.0: 2,
#          30690.0: 4,
#          19690.0: 7,
#          25780.0: 1,
#          42700.0: 5,
#          17495.0: 11,
#          49500.0: 14,
#          40850.0: 1,
#          48000.0: 6,
#          27999.0: 5,
#          8400.0: 4,
#          12599.0: 1,
#          38390.0: 2,
#          36990.0: 36,
#          26700.0: 21,
#          29495.0: 3,
#          22150.0: 1,
#          46890.0: 2,
#          27700.0: 19,
#          16100.0: 28,
#          15495.0: 18,
#          16700.0: 40,
#          27890.0: 14,
#          35800.0: 12,
#          68800.0: 2,
#          17995.0: 9,
#          15995.0: 18,
#          14100.0: 21,
#          15490.0: 65,
#          24290.0: 9,
#          9790.0: 3,
#          6900.0: 6,
#          44990.0: 16,
#          30790.0: 3,
#          49400.0: 2,
#          21600.0: 23,
#          18800.0: 33,
#          11000.0: 18,
#          9600.0: 20,
#          47900.0: 25,
#          18978.0: 1,
#          26218.0: 1,
#          33290.0: 4,
#          16590.0: 9,
#          25550.0: 3,
#          31690.0: 2,
#          20850.0: 5,
#          21990.0: 105,
#          33999.0: 2,
#          9890.0: 5,
#          23386.0: 1,
#          21222.0: 1,
#          17650.0: 6,
#          10800.0: 34,
#          8600.0: 11,
#          32090.0: 1,
#          24190.0: 2,
#          41990.0: 16,
#          27100.0: 7,
#          16200.0: 49,
#          41000.0: 12,
#          78500.0: 2,
#          144900.0: 2,
#          9490.0: 17,
#          13100.0: 10,
#          30250.0: 3,
#          45990.0: 7,
#          39990.0: 23,
#          25490.0: 16,
#          68500.0: 2,
#          30400.0: 20,
#          11600.0: 11,
#          12300.0: 25,
#          20160.0: 1,
#          16980.0: 11,
#          18380.0: 1,
#          34980.0: 1,
#          9980.0: 4,
#          66000.0: 2,
#          38700.0: 14,
#          26250.0: 5,
#          18290.0: 7,
#          17690.0: 12,
#          22190.0: 4,
#          33690.0: 3,
#          20700.0: 26,
#          19507.0: 1,
#          18974.0: 1,
#          23600.0: 15,
#          23917.0: 1,
#          23564.0: 1,
#          20300.0: 46,
#          20200.0: 20,
#          10300.0: 20,
#          27850.0: 10,
#          48900.0: 25,
#          17290.0: 8,
#          29800.0: 23,
#          37690.0: 2,
#          21300.0: 56,
#          57900.0: 9,
#          18000.0: 32,
#          18400.0: 46,
#          15700.0: 49,
#          11250.0: 10,
#          19950.0: 34,
#          10950.0: 6,
#          19450.0: 15,
#          21750.0: 11,
#          16250.0: 32,
#          14838.0: 2,
#          13450.0: 13,
#          10750.0: 8,
#          14330.0: 2,
#          13950.0: 23,
#          27450.0: 4,
#          18950.0: 15,
#          14300.0: 54,
#          11995.0: 11,
#          31890.0: 6,
#          51700.0: 1,
#          59500.0: 5,
#          25800.0: 21,
#          30600.0: 8,
#          24200.0: 18,
#          64850.0: 1,
#          22450.0: 10,
#          27480.0: 1,
#          8650.0: 2,
#          46990.0: 15,
#          20750.0: 26,
#          9850.0: 2,
#          12800.0: 34,
#          44790.0: 1,
#          76500.0: 1,
#          28000.0: 18,
#          31450.0: 3,
#          32690.0: 9,
#          43290.0: 2,
#          43899.0: 1,
#          40300.0: 5,
#          12850.0: 11,
#          27600.0: 18,
#          21490.0: 52,
#          26490.0: 10,
#          30715.0: 1,
#          42995.0: 3,
#          41995.0: 7,
#          28295.0: 3,
#          45295.0: 3,
#          43895.0: 1,
#          26795.0: 8,
#          58895.0: 1,
#          39995.0: 5,
#          16790.0: 11,
#          26495.0: 8,
#          62789.0: 1,
#          19790.0: 5,
#          10490.0: 19,
#          15290.0: 11,
#          31990.0: 36,
#          10100.0: 17,
#          19850.0: 3,
#          23300.0: 24,
#          27400.0: 35,
#          35400.0: 8,
#          24620.0: 5,
#          16975.0: 3,
#          9100.0: 9,
#          9000.0: 8,
#          9400.0: 13,
#          11400.0: 30,
#          21995.0: 11,
#          12000.0: 10,
#          26000.0: 22,
#          13690.0: 3,
#          40950.0: 3,
#          49000.0: 9,
#          16350.0: 9,
#          46070.0: 1,
#          23899.0: 1,
#          12690.0: 9,
#          20600.0: 27,
#          24789.0: 1,
#          34890.0: 3,
#          30800.0: 9,
#          25600.0: 16,
#          34650.0: 3,
#          23850.0: 7,
#          16995.0: 13,
#          47000.0: 7,
#          27000.0: 14,
#          49900.0: 35,
#          45050.0: 1,
#          15850.0: 15,
#          14850.0: 12,
#          21200.0: 26,
#          14490.0: 39,
#          8350.0: 1,
#          10650.0: 1,
#          24100.0: 13,
#          8300.0: 7,
#          39850.0: 4,
#          38850.0: 3,
#          47850.0: 2,
#          29850.0: 9,
#          17800.0: 27,
#          41890.0: 1,
#          16335.0: 2,
#          19890.0: 11,
#          26890.0: 5,
#          26690.0: 6,
#          15230.0: 6,
#          57800.0: 1,
#          17190.0: 9,
#          61790.0: 1,
#          38400.0: 8,
#          29300.0: 20,
#          24700.0: 28,
#          18600.0: 17,
#          15590.0: 3,
#          23595.0: 3,
#          13995.0: 9,
#          22095.0: 3,
#          56595.0: 1,
#          35795.0: 2,
#          28695.0: 3,
#          27195.0: 4,
#          15140.0: 1,
#          16740.0: 2,
#          47550.0: 1,
#          51950.0: 2,
#          39950.0: 4,
#          19290.0: 3,
#          8190.0: 2,
#          18480.0: 7,
#          19495.0: 10,
#          44850.0: 4,
#          34850.0: 4,
#          13400.0: 38,
#          29190.0: 1,
#          29600.0: 18,
#          44800.0: 6,
#          24850.0: 7,
#          49250.0: 1,
#          31000.0: 15,
#          48300.0: 1,
#          45620.0: 1,
#          44620.0: 1,
#          29370.0: 1,
#          35260.0: 1,
#          35700.0: 9,
#          28970.0: 1,
#          28960.0: 1,
#          28870.0: 1,
#          23320.0: 1,
#          24999.0: 3,
#          35890.0: 7,
#          23270.0: 1,
#          29550.0: 1,
#          30700.0: 9,
#          32300.0: 9,
#          36600.0: 6,
#          21100.0: 19,
#          12290.0: 7,
#          23740.0: 1,
#          43278.0: 1,
#          57533.0: 1,
#          63900.0: 12,
#          52500.0: 10,
#          25000.0: 29,
#          45700.0: 3,
#          77900.0: 3,
#          11499.0: 2,
#          32850.0: 3,
#          34450.0: 3,
#          26876.0: 1,
#          33490.0: 11,
#          18272.0: 1,
#          16199.0: 1,
#          20190.0: 4,
#          24650.0: 1,
#          51000.0: 2,
#          20400.0: 35,
#          29135.0: 1,
#          29520.0: 1,
#          29095.0: 3,
#          18750.0: 17,
#          25200.0: 18,
#          11450.0: 13,
#          13750.0: 46,
#          14250.0: 9,
#          14400.0: 32,
#          7950.0: 13,
#          18650.0: 3,
#          18995.0: 7,
#          43000.0: 8,
#          17700.0: 28,
#          38600.0: 7,
#          68900.0: 5,
#          14975.0: 1,
#          40990.0: 13,
#          32490.0: 14,
#          33800.0: 10,
#          26195.0: 2,
#          20595.0: 2,
#          28194.0: 1,
#          48694.0: 1,
#          35495.0: 8,
#          19795.0: 10,
#          27650.0: 5,
#          14700.0: 38,
#          9800.0: 18,
#          191900.0: 1,
#          34400.0: 5,
#          32790.0: 2,
#          14795.0: 3,
#          20995.0: 24,
#          17250.0: 15,
#          25290.0: 4,
#          22995.0: 11,
#          48700.0: 2,
#          79400.0: 1,
#          11590.0: 4,
#          33100.0: 5,
#          47800.0: 6,
#          25850.0: 5,
#          12456.0: 1,
#          17963.0: 1,
#          56000.0: 6,
#          40900.0: 41,
#          32250.0: 4,
#          37700.0: 7,
#          21890.0: 18,
#          22390.0: 7,
#          24495.0: 4,
#          23200.0: 15,
#          22850.0: 15,
#          10390.0: 2,
#          8250.0: 3,
#          22590.0: 3,
#          22790.0: 9,
#          22690.0: 6,
#          21290.0: 5,
#          11200.0: 17,
#          11290.0: 7,
#          8000.0: 2,
#          42450.0: 1,
#          31590.0: 2,
#          52900.0: 15,
#          37000.0: 11,
#          7490.0: 1,
#          96500.0: 4,
#          43700.0: 6,
#          61500.0: 2,
#          60900.0: 5,
#          11100.0: 13,
#          13890.0: 14,
#          16190.0: 5,
#          11190.0: 10,
#          14790.0: 9,
#          27095.0: 6,
#          51995.0: 1,
#          18595.0: 3,
#          31895.0: 4,
#          26950.0: 7,
#          18980.0: 8,
#          39690.0: 2,
#          42690.0: 1,
#          58890.0: 2,
#          45300.0: 6,
#          53990.0: 2,
#          36610.0: 6,
#          17610.0: 2,
#          29610.0: 1,
#          23420.0: 2,
#          7690.0: 1,
#          40600.0: 8,
#          47500.0: 10,
#          32600.0: 8,
#          54200.0: 2,
#          48500.0: 9,
#          39322.0: 1,
#          29440.0: 1,
#          21418.0: 1,
#          21893.0: 1,
#          33669.0: 1,
#          50000.0: 4,
#          16999.0: 1,
#          36850.0: 1,
#          31490.0: 10,
#          79900.0: 9,
#          25750.0: 5,
#          124000.0: 1,
#          16499.0: 2,
#          50890.0: 1,
#          15999.0: 3,
#          13495.0: 1,
#          13195.0: 1,
#          10995.0: 4,
#          16795.0: 5,
#          18495.0: 11,
#          32650.0: 5,
#          9290.0: 7,
#          45900.0: 42,
#          42300.0: 13,
#          46200.0: 1,
#          37600.0: 16,
#          31950.0: 5,
#          31350.0: 1,
#          63700.0: 1,
#          62700.0: 1,
#          42400.0: 6,
#          22563.0: 1,
#          16987.0: 3,
#          28450.0: 1,
#          20790.0: 8,
#          10050.0: 1,
#          21550.0: 2,
#          21590.0: 3,
#          21090.0: 3,
#          13250.0: 6,
#          27995.0: 9,
#          20350.0: 7,
#          44950.0: 1,
#          50900.0: 18,
#          34000.0: 11,
#          33950.0: 3,
#          28090.0: 1,
#          15890.0: 9,
#          15390.0: 5,
#          98950.0: 1,
#          37925.0: 1,
#          26200.0: 15,
#          33000.0: 18,
#          25400.0: 27,
#          27225.0: 3,
#          39809.0: 1,
#          41690.0: 1,
#          20090.0: 4,
#          22800.0: 23,
#          75000.0: 8,
#          14390.0: 5,
#          24980.0: 3,
#          22200.0: 14,
#          35550.0: 2,
#          52000.0: 6,
#          39580.0: 1,
#          34330.0: 1,
#          99000.0: 2,
#          89000.0: 2,
#          106000.0: 1,
#          38456.0: 1,
#          46000.0: 10,
#          46276.0: 1,
#          44232.0: 1,
#          44028.0: 1,
#          25999.0: 6,
#          76900.0: 11,
#          21450.0: 30,
#          12950.0: 8,
#          10000.0: 3,
#          11790.0: 4,
#          19590.0: 4,
#          46450.0: 1,
#          10590.0: 7,
#          17225.0: 1,
#          29470.0: 1,
#          9950.0: 16,
#          36950.0: 5,
#          24490.0: 12,
#          11130.0: 1,
#          12955.0: 2,
#          12395.0: 3,
#          48990.0: 6,
#          28300.0: 23,
#          10870.0: 2,
#          10970.0: 1,
#          10890.0: 3,
#          10364.0: 1,
#          39400.0: 7,
#          30390.0: 3,
#          37400.0: 11,
#          43400.0: 7,
#          92400.0: 2,
#          46400.0: 3,
#          32895.0: 1,
#          19995.0: 5,
#          13150.0: 6,
#          11390.0: 3,
#          17590.0: 6,
#          15790.0: 6,
#          43950.0: 1,
#          40995.0: 3,
#          44995.0: 3,
#          43595.0: 2,
#          76995.0: 1,
#          26295.0: 4,
#          28495.0: 5,
#          53995.0: 1,
#          21095.0: 2,
#          26695.0: 3,
#          25295.0: 2,
#          23295.0: 3,
#          31095.0: 1,
#          39595.0: 2,
#          42195.0: 3,
#          33995.0: 4,
#          72995.0: 1,
#          32995.0: 2,
#          34895.0: 2,
#          11795.0: 1,
#          79195.0: 1,
#          73695.0: 1,
#          70095.0: 1,
#          74295.0: 1,
#          27795.0: 5,
#          49995.0: 1,
#          10200.0: 15,
#          47890.0: 1,
#          31390.0: 1,
#          57890.0: 1,
#          43890.0: 3,
#          39325.0: 2,
#          52490.0: 1,
#          16690.0: 18,
#          15000.0: 31,
#          44100.0: 2,
#          35000.0: 12,
#          29250.0: 1,
#          24987.0: 2,
#          33650.0: 1,
#          12450.0: 5,
#          22250.0: 4,
#          25300.0: 28,
#          63723.0: 1,
#          61680.0: 1,
#          78121.0: 1,
#          32999.0: 5,
#          10400.0: 7,
#          36820.0: 1,
#          124900.0: 1,
#          13395.0: 2,
#          36700.0: 11,
#          10285.0: 3,
#          15190.0: 5,
#          7200.0: 1,
#          9200.0: 7,
#          101500.0: 1,
#          31185.0: 2,
#          44550.0: 1,
#          66450.0: 3,
#          53350.0: 3,
#          63300.0: 3,
#          8100.0: 4,
#          31400.0: 9,
#          18795.0: 14,
#          12905.0: 1,
#          16595.0: 1,
#          12790.0: 5,
#          8825.0: 1,
#          8770.0: 2,
#          8820.0: 1,
#          ...})

# %%
Counter(df_cars['fuel'])
# Out:
# Counter({'Diésel': 10844,
#          'Gasolina': 11925,
#          'Híbrido': 2014,
#          'Eléctrico': 1307,
#          'Gas': 82,
#          'Gas natural (CNG)': 130,
#          'Automático': 6})

# %%
df_cars[df_cars['fuel'] == 'Automático']
# Out:
#                brand                                              model  \
# 5065            Audi  Q7 3.0 TDI E-TRON QUATTRO TIPTRONIC DESIGN 4X4...
# 5066             BMW                          X5 40 E XDRIVE 4X4 HYBRID
# 15477            Kia                                         Niro Drive
# 15478            Kia                                         XCeed Tech
# 24435           Audi         A3 e-tron A-3 SPORTBACK 40 S LINE  STRONIC
# 25816  Mercedes-Benz                                ASE E 300 e BERLINA
#
#          price        fuel transmission  km    year   location
# 5065   51490.0  Automático    68.496 km NaN  2016.0     Madrid
# 5066   37990.0  Automático    52.874 km NaN  2016.0     Madrid
# 15477  25900.0  Automático     3.316 km NaN  2020.0      Cádiz
# 15478  23900.0  Automático    13.100 km NaN  2020.0      Cádiz
# 24435  32900.0  Automático     1.500 km NaN  2019.0  Tarragona
# 25816  55400.0  Automático     3.333 km NaN  2019.0    Córdoba

# %%
fuel_error = list(df_cars[df_cars['fuel'] == 'Automático'].index)

# %%
df_cars['km'].iloc[i]
# Out:
# 1.0

# %%
for i in fuel_error:
    df_cars['km'].iloc[i] = float(df_cars['transmission'].iloc[i].strip('\xa0km').replace('.',''))
    df_cars['transmission'].iloc[i] = df_cars['fuel'].iloc[i]
    df_cars['fuel'].iloc[i] = 'Híbrido'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
for i in fuel_error:
    print(df_cars['km'].iloc[i])
    print(df_cars['transmission'].iloc[i])
    print(df_cars['fuel'].iloc[i])
# Out:
# 68496.0
# Automático
# Híbrido
# 52874.0
# Automático
# Híbrido
# 3316.0
# Automático
# Híbrido
# 13100.0
# Automático
# Híbrido
# 1500.0
# Automático
# Híbrido
# 3333.0
# Automático
# Híbrido

# %%
df_cars[df_cars.year.isnull()]
# Out:
#      brand                             model    price     fuel transmission  \
# 7426   Kia  Ceed Tourer 1.6 PHEV Tech (MY21)  28800.0  Híbrido   Automático
#
#        km  year location
# 7426  1.0   NaN    Cádiz

# %%
df_cars['year'].iloc[7426] = 2021
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_cars['year'].iloc[7426]
# Out:
# 2021.0

# %%
df_cars[df_cars.km.isnull()]
# Out:
#                brand                                       model    price  \
# 176    Mercedes-Benz                CLA 220 D DCT Shooting Brake  47600.0
# 178    Mercedes-Benz       CLA 200 Shooting Brake Shooting Brake  39700.0
# 1340   Mercedes-Benz                            GLE 300 d 4MATIC  78500.0
# 1341   Mercedes-Benz                                    CLA 200   39700.0
# 1342   Mercedes-Benz                                     A 200 d  39700.0
# ...              ...                                         ...      ...
# 24648          Volvo              V60 V60 D3 Momentum Automático  27500.0
# 24914           Ford         Fiesta 1.1 PFI GLP 55kW 75CV STLine  16970.0
# 25079     Land Rover  Range Rover Sport 3.0 SDV6 183kW 249CV HSE  91690.0
# 25198         Jaguar    XE 2.0D I4 132kW 180CV AWD AT RDynamic S  58890.0
# 25201         Jaguar             XF 2.0D 132kW 180CV RSport Auto  65690.0
#
#            fuel transmission  km    year   location
# 176      Diésel   Automático NaN  2021.0    Sevilla
# 178    Gasolina   Automático NaN  2021.0    Sevilla
# 1340     Diésel   Automático NaN  2021.0    Sevilla
# 1341   Gasolina   Automático NaN  2021.0    Sevilla
# 1342     Diésel   Automático NaN  2021.0    Sevilla
# ...         ...          ...  ..     ...        ...
# 24648    Diésel   Automático NaN  2019.0   Albacete
# 24914       Gas       Manual NaN  2019.0     Madrid
# 25079    Diésel   Automático NaN  2019.0  Barcelona
# 25198    Diésel   Automático NaN  2020.0  Barcelona
# 25201    Diésel   Automático NaN  2019.0  Barcelona
#
# [126 rows x 8 columns]

# %%
Counter(df_cars['location'])
# Out:
# Counter({'Alava': 262,
#          'Madrid': 4848,
#          'Barcelona': 4205,
#          'Soria': 11,
#          'Valencia': 1240,
#          'Burgos': 296,
#          'Vizcaya': 371,
#          'Zamora': 56,
#          'Córdoba': 943,
#          'Cádiz': 652,
#          'Murcia': 670,
#          'Málaga': 1925,
#          'Almería': 862,
#          'Granada': 693,
#          'Alicante': 637,
#          'Baleares': 979,
#          'Gerona': 289,
#          'Jaén': 280,
#          'Sevilla': 1110,
#          'Navarra': 168,
#          'Pontevedra': 638,
#          'La Coruña': 677,
#          'Palencia': 53,
#          'La Rioja': 127,
#          'Albacete': 150,
#          'Tarragona': 601,
#          'Huesca': 172,
#          'Huelva': 117,
#          'Lugo': 191,
#          'Asturias': 585,
#          'Guipúzcoa': 415,
#          'Castellón': 153,
#          'León': 70,
#          'Ávila': 152,
#          'Badajoz': 88,
#          'Toledo': 485,
#          'Cáceres': 93,
#          'Valladolid': 116,
#          'Zaragoza': 314,
#          'Cantabria': 99,
#          'Orense': 204,
#          'Ciudad Real': 84,
#          'Salamanca': 158,
#          'Guadalajara': 51,
#          'Teruel': 6,
#          'Cuenca': 4,
#          'Las Palmas': 8})

# %%
fig, ax = plt.subplots (figsize = (32,18))
brands = sns.barplot(x="brand", y="price", data=df_cars)
for item in brands.get_xticklabels():
    item.set_rotation(80)
plt.show()

# %%
sns.boxplot(data=df_cars.year)
# Out:
# <AxesSubplot:>

# %%
df_cars.year.unique()
# Out:
# array([2017., 2020., 2018., 2019., 2021., 2016., 2015., 1970.])

# %%
df_cars[df_cars['year'] == 1970]
# Out:
#        brand                                      model    price       fuel  \
# 18825    Kia   Sportage 1.6 MHEV Drive 85kW (115CV) 4x2  26995.0  Eléctrico
# 20906  Smart                 fortwo 60kW(81CV) EQ coupe  26550.0  Eléctrico
# 24517    Kia  Sportage 1.6 MHEV 85KW CONCEPT 2WD 115 5P  24965.0  Eléctrico
#
#       transmission   km    year   location
# 18825       Manual  1.0  1970.0  Barcelona
# 20906   Automático  1.0  1970.0  Barcelona
# 24517       Manual  1.0  1970.0     Málaga

# %%
year_error = list(df_cars[df_cars.year == 1970].index)

# %%
for i in year_error:
    df_cars['year'].iloc[i] = 2020
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(data=df_cars.year)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df_cars.price)
# Out:
# <AxesSubplot:>

# %%
df_cars[df_cars['price']>50000]
# Out:
#                brand                                             model  \
# 15        Land Rover    Range Rover Sport 3.0 TDV6 HSE AUTO 4WD 258 5P
# 85        Land Rover          Range Rover 3.0 SDV6 202kW (275CV) VOGUE
# 88        Land Rover          Range Rover 3.0 SDV6 202kW (275CV) VOGUE
# 107       Land Rover          Range Rover 3.0 SDV6 202kW (275CV) VOGUE
# 118              BMW                      X5 xDrive40i 250 kW (340 CV)
# ...              ...                                               ...
# 26223  Mercedes-Benz                                       GLS 350 AMG
# 26227     Land Rover  Range Rover Sport 3.0 SDV6 249 CV HSE 7 asientos
# 26257     Land Rover        Range Rover Sport 2.0P Si4 PHEV 404 CV HSE
# 26258         Jaguar                          I-Pace EV 400 CV AWD HSE
# 26274  Mercedes-Benz                  S 4MATIC+ COUPÉ 4 PUERTAS[0-809]
#
#           price       fuel transmission       km    year   location
# 15      53900.0     Diésel   Automático  39189.0  2018.0    Córdoba
# 85     102455.0     Diésel   Automático      5.0  2020.0     Málaga
# 88     102455.0     Diésel   Automático      5.0  2020.0    Almería
# 107    102455.0     Diésel   Automático      5.0  2020.0    Granada
# 118     64900.0   Gasolina   Automático  40003.0  2018.0   Alicante
# ...         ...        ...          ...      ...     ...        ...
# 26223   63900.0     Diésel   Automático  77100.0  2016.0   Zaragoza
# 26227   69996.0     Diésel   Automático   6480.0  2019.0     Madrid
# 26257   79998.0    Híbrido   Automático   4520.0  2019.0     Madrid
# 26258   65995.0  Eléctrico   Automático  15742.0  2018.0     Madrid
# 26274  182900.0   Gasolina   Automático    150.0  2019.0  La Coruña
#
# [1023 rows x 8 columns]

# %%
df_cars[df_cars['price']>300000]
# Out:
#          brand                             model     price      fuel  \
# 172    Bentley  Continental GT GT V8 Convertible  307900.0  Gasolina
# 5211   Bentley  Continental GT GT V8 Convertible  307900.0  Gasolina
# 11966  Ferrari                            SPIDER  411730.0  Gasolina
# 23186  Ferrari                     812 Superfast  355000.0  Gasolina
#
#       transmission      km    year location
# 172     Automático    50.0  2021.0   Madrid
# 5211    Automático    50.0  2021.0   Málaga
# 11966   Automático    55.0  2020.0   Málaga
# 23186   Automático  1800.0  2019.0   Málaga

# %%
df_cars.groupby('brand', axis = 0).describe()
# Out:
#                 price                                                    \
#                 count           mean           std       min        25%
# brand
# ALPINE            4.0   54150.000000   4500.000000   51900.0   51900.00
# Abarth           39.0   22899.743590   4431.923360   13900.0   19600.00
# Alfa Romeo      108.0   29495.925926  11294.042598    8500.0   19650.00
# Aston Martin      2.0  190500.000000   2121.320344  189000.0  189750.00
# Audi           2366.0   32563.760778  13140.855757   11900.0   23990.00
# BMW            1448.0   33549.354972  15870.818555   12490.0   23500.00
# Bentley           9.0  272786.666667  36543.391673  216750.0  259900.00
# Citroen         784.0   16819.917092   8463.840134    7000.0   13400.00
# Cupra            27.0   37961.296296   5613.931433   29900.0   34900.00
# DFSK              2.0   20495.000000   4942.676400   17000.0   18747.50
# DS               72.0   25398.666667   9524.324666    8600.0   16900.00
# Dacia           109.0   12668.935780   3307.487959    6750.0    9900.00
# Drexel            1.0   15900.000000           NaN   15900.0   15900.00
# Ferrari           4.0  331586.250000  66126.082521  260000.0  289711.25
# Fiat            807.0   12844.246592   4074.751428    6500.0   10250.00
# Ford           1737.0   17647.805412   7651.701994    6900.0   12180.00
# Honda           136.0   25491.786765  18840.679608   10900.0   19200.00
# Hyundai        1002.0   19145.372255   7350.847357    6990.0   13890.00
# Infiniti         15.0   21533.333333   3976.415591   17900.0   17945.00
# Jaguar          146.0   47130.842466  14999.602067   17900.0   36516.00
# Jeep            266.0   28318.097744   8617.361941   12900.0   22425.00
# Kia             860.0   20480.045349   9935.200271    7000.0   15690.00
# Land Rover      202.0   55377.381188  18738.746360   22500.0   41900.00
# Lexus           211.0   35497.199052  12999.789774   12900.0   27875.00
# MINI            449.0   23947.824053   6687.018079   13200.0   18550.00
# Mahindra          2.0   24900.000000      0.000000   24900.0   24900.00
# Maserati         20.0   82915.000000  17188.223478   59000.0   67850.00
# Mazda           179.0   23666.877095   5885.037777   11800.0   18242.50
# Mercedes-Benz  2021.0   36885.400792  15121.811880    8230.0   27795.00
# Mitsubishi       97.0   22857.618557   8712.589204    7900.0   13900.00
# Nissan         1309.0   20209.128342   5925.524913    7900.0   15700.00
# Opel           1489.0   18157.885829   6344.757323    7100.0   14900.00
# Peugeot        1145.0   19580.075109   7175.107248    6990.0   13900.00
# Porsche          71.0  113360.422535  27002.013652   50900.0   95445.00
# Renault        2325.0   19090.623656   5720.579010    5850.0   15050.00
# Seat           1993.0   19414.081284   5837.474768    6300.0   15900.00
# Skoda           467.0   18874.755889   7055.698303    6450.0   13490.00
# Smart           146.0   15776.726027   4666.818979    7900.0   12525.00
# SsangYong        54.0   20785.888889   5735.135545   11600.0   18092.50
# Subaru           25.0   28066.600000   3872.178736   21900.0   23900.00
# Suzuki          109.0   22341.477064   9214.434938    9300.0   16200.00
# Tesla             2.0   62945.000000  22563.777388   46990.0   54967.50
# Toyota          854.0   17427.614754   5799.721810    6900.0   13400.00
# Volkswagen     2523.0   22912.172810   8748.214572    7900.0   16900.00
# Volvo           671.0   39161.992548  12376.959273   12900.0   32750.00
#
#                                                   km                ...  \
#                     50%        75%       max   count          mean  ...
# brand                                                               ...
# ALPINE          51900.0   54150.00   60900.0     4.0  44855.000000  ...
# Abarth          23990.0   26545.00   29800.0    39.0  10906.897436  ...
# Alfa Romeo      29950.0   41050.00   47500.0   108.0  20341.250000  ...
# Aston Martin   190500.0  191250.00  192000.0     2.0  18000.000000  ...
# Audi            29900.0   37400.00  127990.0  2365.0  26012.244820  ...
# BMW             29900.0   37978.75  126900.0  1443.0  33761.948025  ...
# Bentley        287980.0  299000.00  307900.0     9.0   5614.333333  ...
# Citroen         15200.0   17900.00  191900.0   783.0  20852.210728  ...
# Cupra           36900.0   41945.00   48900.0    27.0   2359.777778  ...
# DFSK            20495.0   22242.50   23990.0     2.0   4650.000000  ...
# DS              24925.0   31990.00   49990.0    72.0  26142.458333  ...
# Dacia           12990.0   14990.00   21500.0   109.0  32658.100917  ...
# Drexel          15900.0   15900.00   15900.0     1.0  13600.000000  ...
# Ferrari        327307.5  369182.50  411730.0     4.0   2172.250000  ...
# Fiat            11900.0   14500.00   33800.0   807.0  25657.768278  ...
# Ford            16000.0   21190.00   66990.0  1733.0  25400.818811  ...
# Honda           22900.0   26247.50  229500.0   134.0  25391.067164  ...
# Hyundai         18250.0   22990.00   46590.0   990.0  18140.218182  ...
# Infiniti        20900.0   24445.00   29950.0    15.0  61935.866667  ...
# Jaguar          44872.0   54965.00   93000.0   140.0  17216.921429  ...
# Jeep            25945.0   31710.00   55990.0   266.0  13358.642857  ...
# Kia             17990.0   24900.00  229000.0   860.0  16990.129070  ...
# Land Rover      51935.0   69900.00  115000.0   193.0  23647.989637  ...
# Lexus           31900.0   42200.00   98950.0   210.0  21869.047619  ...
# MINI            23100.0   28900.00   47990.0   449.0  29260.106904  ...
# Mahindra        24900.0   24900.00   24900.0     2.0   3550.000000  ...
# Maserati        83100.0   94625.00  115300.0    20.0  17169.600000  ...
# Mazda           24500.0   28500.00   35990.0   179.0  18363.379888  ...
# Mercedes-Benz   32900.0   42100.00  182900.0  1972.0  28601.966024  ...
# Mitsubishi      23400.0   26990.00   38900.0    97.0  19971.649485  ...
# Nissan          21000.0   23400.00  105500.0  1309.0  19657.928189  ...
# Opel            16900.0   19990.00   45900.0  1489.0  18756.281397  ...
# Peugeot         17990.0   24900.00   42900.0  1145.0  27738.957205  ...
# Porsche        109900.0  133350.00  162000.0    71.0  21538.042254  ...
# Renault         18490.0   21900.00   70000.0  2323.0  19797.976324  ...
# Seat            17990.0   21990.00   46900.0  1993.0  19004.765178  ...
# Skoda           17900.0   21990.00   48800.0   466.0  19587.965665  ...
# Smart           14400.0   18569.25   28800.0   146.0  16879.869863  ...
# SsangYong       19247.5   23400.00   39900.0    54.0  15292.759259  ...
# Subaru          29500.0   30900.00   32895.0    25.0  14392.400000  ...
# Suzuki          22500.0   24900.00   50600.0   109.0   7044.908257  ...
# Tesla           62945.0   70922.50   78900.0     2.0  22339.000000  ...
# Toyota          16990.0   20937.50   60640.0   847.0  40417.335301  ...
# Volkswagen      21190.0   27445.00   77400.0  2523.0  29706.059057  ...
# Volvo           38900.0   45485.00   90649.0   645.0  19230.013953  ...
#
#                                      year                                 \
#                     75%       max   count         mean       std     min
# brand
# ALPINE         58140.00   58140.0     4.0  2019.000000  0.000000  2019.0
# Abarth         21000.00   54903.0    39.0  2019.230769  1.286806  2016.0
# Alfa Romeo     36554.00   99258.0   108.0  2019.037037  1.267317  2016.0
# Aston Martin   24000.00   30000.0     2.0  2019.000000  0.000000  2019.0
# Audi           30992.00  225356.0  2366.0  2018.794167  1.282301  2016.0
# BMW            51312.50  205816.0  1448.0  2018.265193  1.414254  2015.0
# Bentley         2900.00   22276.0     9.0  2020.111111  0.781736  2019.0
# Citroen        27961.00  153683.0   784.0  2019.061224  1.219814  2015.0
# Cupra           4605.50    9726.0    27.0  2020.148148  0.362014  2020.0
# DFSK            6575.00    8500.0     2.0  2019.000000  0.000000  2019.0
# DS             39983.75  165029.0    72.0  2018.625000  1.495886  2016.0
# Dacia          45562.00  167923.0   109.0  2018.550459  1.499915  2016.0
# Drexel         13600.00   13600.0     1.0  2019.000000       NaN  2019.0
# Ferrari         2939.50    4372.0     4.0  2019.250000  0.957427  2018.0
# Fiat           35635.00  311200.0   807.0  2018.809170  1.095112  2015.0
# Ford           42537.00  350605.0  1737.0  2018.709269  1.264588  2016.0
# Honda          48525.00  135000.0   136.0  2018.845588  1.429212  2015.0
# Hyundai        25534.00  149000.0  1002.0  2019.042914  1.044062  2015.0
# Infiniti       99939.50  124029.0    15.0  2017.333333  1.112697  2015.0
# Jaguar         19427.75  153008.0   146.0  2019.109589  1.238037  2015.0
# Jeep           20240.50   92498.0   266.0  2019.428571  1.062469  2016.0
# Kia            22000.00  158000.0   860.0  2019.146512  1.154804  2016.0
# Land Rover     20390.00  194006.0   202.0  2019.059406  1.264296  2016.0
# Lexus          23831.75  157545.0   211.0  2019.061611  1.383920  2016.0
# MINI           42742.00  185000.0   449.0  2018.296214  1.364083  2015.0
# Mahindra        5275.00    7000.0     2.0  2019.500000  0.707107  2019.0
# Maserati       31000.00   56000.0    20.0  2018.400000  1.353358  2016.0
# Mazda          24274.50  152350.0   179.0  2018.988827  1.365666  2015.0
# Mercedes-Benz  40008.50  380342.0  2021.0  2018.645225  1.357893  2015.0
# Mitsubishi     25326.00  139114.0    97.0  2019.237113  1.328950  2016.0
# Nissan         25800.00  155270.0  1309.0  2018.822002  1.100294  2015.0
# Opel           29680.00  145000.0  1489.0  2019.203492  1.104531  2015.0
# Peugeot        38312.00  204516.0  1145.0  2018.811354  1.366831  2015.0
# Porsche        24932.00  151800.0    71.0  2018.859155  0.975350  2016.0
# Renault        25000.00  177793.0  2325.0  2018.992688  1.161427  2015.0
# Seat           22879.00  164219.0  1993.0  2019.125941  0.947780  2015.0
# Skoda          20555.75  185697.0   467.0  2019.111349  1.173939  2015.0
# Smart          26462.50  127000.0   146.0  2018.342466  1.283521  2015.0
# SsangYong      15100.00   87200.0    54.0  2019.129630  1.360442  2016.0
# Subaru         22163.00   59000.0    25.0  2019.080000  1.288410  2016.0
# Suzuki          7000.00  101268.0   109.0  2019.825688  0.901070  2016.0
# Tesla          26169.50   30000.0     2.0  2019.500000  0.707107  2019.0
# Toyota         60283.00  760001.0   854.0  2018.008197  1.521608  2015.0
# Volkswagen     40429.00  195303.0  2523.0  2018.850971  1.202358  2015.0
# Volvo          27779.00  142562.0   671.0  2019.052161  1.295903  2015.0
#
#
#                    25%     50%      75%     max
# brand
# ALPINE         2019.00  2019.0  2019.00  2019.0
# Abarth         2018.50  2020.0  2020.00  2021.0
# Alfa Romeo     2018.00  2019.0  2020.00  2021.0
# Aston Martin   2019.00  2019.0  2019.00  2019.0
# Audi           2018.00  2019.0  2020.00  2021.0
# BMW            2017.00  2018.0  2019.00  2021.0
# Bentley        2020.00  2020.0  2021.00  2021.0
# Citroen        2018.00  2019.0  2020.00  2021.0
# Cupra          2020.00  2020.0  2020.00  2021.0
# DFSK           2019.00  2019.0  2019.00  2019.0
# DS             2017.00  2019.0  2020.00  2021.0
# Dacia          2017.00  2019.0  2020.00  2021.0
# Drexel         2019.00  2019.0  2019.00  2019.0
# Ferrari        2018.75  2019.5  2020.00  2020.0
# Fiat           2018.00  2019.0  2019.00  2021.0
# Ford           2018.00  2019.0  2020.00  2021.0
# Honda          2018.00  2019.0  2020.00  2021.0
# Hyundai        2018.00  2019.0  2020.00  2021.0
# Infiniti       2017.00  2017.0  2018.00  2020.0
# Jaguar         2019.00  2019.5  2020.00  2021.0
# Jeep           2019.00  2020.0  2020.00  2021.0
# Kia            2018.00  2019.0  2020.00  2021.0
# Land Rover     2019.00  2020.0  2020.00  2021.0
# Lexus          2019.00  2020.0  2020.00  2021.0
# MINI           2017.00  2018.0  2020.00  2021.0
# Mahindra       2019.25  2019.5  2019.75  2020.0
# Maserati       2017.00  2019.0  2019.25  2020.0
# Mazda          2018.00  2020.0  2020.00  2021.0
# Mercedes-Benz  2018.00  2019.0  2020.00  2021.0
# Mitsubishi     2019.00  2020.0  2020.00  2021.0
# Nissan         2018.00  2019.0  2019.00  2021.0
# Opel           2018.00  2020.0  2020.00  2021.0
# Peugeot        2018.00  2019.0  2020.00  2021.0
# Porsche        2018.00  2019.0  2020.00  2021.0
# Renault        2019.00  2019.0  2020.00  2021.0
# Seat           2019.00  2019.0  2020.00  2021.0
# Skoda          2019.00  2019.0  2020.00  2021.0
# Smart          2017.00  2019.0  2019.00  2021.0
# SsangYong      2019.00  2020.0  2020.00  2021.0
# Subaru         2019.00  2019.0  2020.00  2020.0
# Suzuki         2020.00  2020.0  2020.00  2021.0
# Tesla          2019.25  2019.5  2019.75  2020.0
# Toyota         2017.00  2018.0  2019.00  2021.0
# Volkswagen     2018.00  2019.0  2020.00  2021.0
# Volvo          2019.00  2019.0  2020.00  2021.0
#
# [45 rows x 24 columns]

# %%
fig, ax = plt.subplots (figsize = (32,18))
brands = sns.barplot(x="fuel", y="price", data=df_cars)
plt.show()

# %%
fig, ax = plt.subplots (figsize = (50,25))
fuels = sns.countplot(df_cars['brand'], hue = df_cars['fuel'])
for item in fuels.get_xticklabels():
    item.set_rotation(80)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fuel_dum = pd.get_dummies(df_cars.fuel, drop_first = True)
brand_dum = pd.get_dummies(df_cars.brand, drop_first = True)

# %%
df_cars = pd.concat([df_cars, fuel_dum], axis = 1)

# %%
df_cars = pd.concat([df_cars, brand_dum], axis = 1)

# %%
df_cars.shape
# Out:
# (26308, 57)

# %%
df_cars.drop('fuel', axis = 1, inplace = True)

# %%
sns.heatmap(df_cars.corr(), cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
keys = list(df_cars['brand'].unique()) 
values = [i for i in range(45)]

# %%
df_cars['bmap'] = df_cars['brand'].map({'Renault': 0,
                                         'Volkswagen': 1,
                                         'Hyundai': 2,
                                         'Nissan': 3,
                                         'Cupra': 4,
                                         'Ford': 5,
                                         'Seat': 6,
                                         'Dacia': 7,
                                         'Land Rover': 8,
                                         'BMW': 9,
                                         'Volvo': 10,
                                         'Peugeot': 11,
                                         'Kia': 12,
                                         'Opel': 13,
                                         'Citroen': 14,
                                         'MINI': 15,
                                         'Audi': 16,
                                         'Fiat': 17,
                                         'Subaru': 18,
                                         'Mazda': 19,
                                         'DS': 20,
                                         'Honda': 21,
                                         'Skoda': 22,
                                         'Abarth': 23,
                                         'Bentley': 24,
                                         'Mercedes-Benz': 25,
                                         'Toyota': 26,
                                         'Jeep': 27,
                                         'Mitsubishi': 28,
                                         'Suzuki': 29,
                                         'Smart': 30,
                                         'Lexus': 31,
                                         'Alfa Romeo': 32,
                                         'Infiniti': 33,
                                         'Jaguar': 34,
                                         'Maserati': 35,
                                         'Porsche': 36,
                                         'Tesla': 37,
                                         'SsangYong': 38,
                                         'DFSK': 39,
                                         'Drexel': 40,
                                         'Ferrari': 41,
                                         'ALPINE': 42,
                                         'Mahindra': 43,
                                         'Aston Martin': 44})

# %%
sns.heatmap(df_cars[["bmap","price","km"]].corr(), annot = True)
# Out:
# <AxesSubplot:>
